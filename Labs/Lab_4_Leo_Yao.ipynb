# %% [markdown]
# # **Lab 4: Aequitas, Intersectionality, and The Fairness Tree**
#
# In this lab, we will explore [**Aequitas**](http://www.datasciencepublicpolicy.org/our-work/tools-guides/aequitas/), a different python library for discovering fairness concerns in data. Unlike fairLearn, Aequitas does NOT have any mitigation tools, like the `CorrelationRemover` from last week. It only detects bias. However, it gives great plots out of the box!
#
#
# Unlike previous labs, we will also explore **Intersectionality**, or how bias for *Black Women* can be significantly worse than bias towards *Black people* and the bias towards *Women*. You will have to write the code to produce these plots.
#
# Lastly, we will explore **The Fairness Tree**, a flow chart created by the [Data Science and Public Policy Lab at CMU](http://www.datasciencepublicpolicy.org/) to help find some fairness measures that can be relevant in your upcomming fair machine learning problems, though you will have to think about the stakeholders on your own still.
#
# ---
#
# *Official publication on the Aequitas toolkit: https://arxiv.org/pdf/1811.05577.pdf. The concents of this tutorial are based on the offical Aequitas tutorial, which can be found here: https://dssg.github.io/aequitas/examples/compas_demo.html*

# %% [markdown]
# #0. Install Libraries

# %%
# %%capture
#@markdown
# !pip install aequitas
# !pip install folktables
# !git clone https://github.com/lurosenb/superquail
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: aequitas in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (1.0.0)
# Requirement already satisfied: matplotlib>=3.0.3 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (3.4.1)
# Requirement already satisfied: pandas>=0.24.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (2.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (6.0.1)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.13.2)
# Requirement already satisfied: altair>=4.1.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (5.2.0)
# Requirement already satisfied: millify==0.1.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.1.1)
# Requirement already satisfied: scipy>=0.18.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (1.12.0)
# Requirement already satisfied: optuna>=3.0.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (3.5.0)
# Requirement already satisfied: aif360>=0.5.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.5.0)
# Requirement already satisfied: fairgbm==0.9.14 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.9.14)
# Requirement already satisfied: fairlearn>=0.8.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.9.0)
# Requirement already satisfied: hydra-core>=1.3.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (1.3.2)
# Requirement already satisfied: validators>=0.22.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.22.0)
# Requirement already satisfied: hyperparameter-tuning>=0.3.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (0.3.1)
# Requirement already satisfied: numpy==1.23.5 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from aequitas) (1.23.5)
# Requirement already satisfied: wheel in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from fairgbm==0.9.14->aequitas) (0.37.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from fairgbm==0.9.14->aequitas) (1.4.0)
# Requirement already satisfied: jinja2 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from altair>=4.1.0->aequitas) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from altair>=4.1.0->aequitas) (4.21.1)
# Requirement already satisfied: packaging in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from altair>=4.1.0->aequitas) (23.2)
# Requirement already satisfied: toolz in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from altair>=4.1.0->aequitas) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from altair>=4.1.0->aequitas) (4.9.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from hydra-core>=1.3.0->aequitas) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from hydra-core>=1.3.0->aequitas) (4.9.3)
# Requirement already satisfied: schema in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from hyperparameter-tuning>=0.3.1->aequitas) (0.7.5)
# Requirement already satisfied: cycler>=0.10 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0.3->aequitas) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0.3->aequitas) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0.3->aequitas) (10.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0.3->aequitas) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0.3->aequitas) (2.8.2)
# Requirement already satisfied: alembic>=1.5.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from optuna>=3.0.0->aequitas) (1.13.1)
# Requirement already satisfied: colorlog in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from optuna>=3.0.0->aequitas) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from optuna>=3.0.0->aequitas) (2.0.27)
# Requirement already satisfied: tqdm in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from optuna>=3.0.0->aequitas) (4.66.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from pandas>=0.24.1->aequitas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from pandas>=0.24.1->aequitas) (2023.4)
# Requirement already satisfied: Mako in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from alembic>=1.5.0->optuna>=3.0.0->aequitas) (1.3.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair>=4.1.0->aequitas) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair>=4.1.0->aequitas) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair>=4.1.0->aequitas) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair>=4.1.0->aequitas) (0.18.0)
# Requirement already satisfied: six>=1.5 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->aequitas) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from scikit-learn!=0.22.0->fairgbm==0.9.14->aequitas) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from scikit-learn!=0.22.0->fairgbm==0.9.14->aequitas) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from jinja2->altair>=4.1.0->aequitas) (2.1.5)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from schema->hyperparameter-tuning>=0.3.1->aequitas) (21.6.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folktables in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (0.0.12)
# Requirement already satisfied: numpy in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from folktables) (1.23.5)
# Requirement already satisfied: pandas in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from folktables) (2.2.0)
# Requirement already satisfied: requests in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from folktables) (2.31.0)
# Requirement already satisfied: scikit-learn in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from folktables) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from pandas->folktables) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from pandas->folktables) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from pandas->folktables) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from requests->folktables) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from requests->folktables) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from requests->folktables) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from requests->folktables) (2024.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from scikit-learn->folktables) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from scikit-learn->folktables) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from scikit-learn->folktables) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/leoyaoair23/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->folktables) (1.16.0)
# fatal: destination path 'superquail' already exists and is not an empty directory.

# %%
#@title
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from folktables import ACSDataSource, ACSEmployment, ACSIncome, ACSPublicCoverage, ACSMobility, ACSTravelTime
from sklearn.preprocessing import StandardScaler
import seaborn as sns

import matplotlib.pyplot as plt
from IPython.display import clear_output

from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness
from aequitas.plotting import Plot

# %% [markdown]
# #1. Load data
#
# We begin by loading our data. Like before, this data is from the American Community Survey (also called "[Folktables](https://github.com/socialfoundations/folktables)"), and contains individual-level data related to income, employment, health, transportation, and housing. The data has millions of records total, and sensitive attributes include race and sex. It includes 5 separate pre-defined prediction tasks. Today, we will be using data from New York in 2018.
#
# For this lab, we will predict if someone is employed (`ESR`). It's less obvious why people care about this task, but for instance consider:
# - A dating app is trying to match people up, and not everyone lists their job. Many people prefer to look for an employed partner the, so wants to secretly infer who is and isn't employed, and use this to match people up.
# - This dating app does not want to label people as employed based on their race and sex.
#
# For simplicity, we will also aggregate `RAC1P` down from 8 categories to just 4: people who are only White, only Black, only Asian, and everyone else.
#
# ---
#
# **Age:** This dataset will only have people between the ages of 16 and 90.
#
#
# **Race versus Ethnicity**: in Folktables, ethnicity is a seperate feature from race. So looking at *only the race feature* might hide important traits about people (for example, dataset may identify someone as `race=White` and `ethnicity=Latinx/Hispanic`). Today, we will only use the race feature (`RAC1P`), and we will not use ethnicity (`HISP`). So, this lab is for education purposes, and does not fully illustrate the issues of intersectionality.
#
# For more information about the Folktables features, see page 31 here: https://eaamo2021.eaamo.org/accepted/acceptednonarchival/EAMO21_paper_16.pdf

# %%
#@markdown Import Data. The code is slightly different from before since we are picking data from NY specifically.
data_source = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
acs_data = data_source.get_data(states=["NY"], download=True)

# %%
#@title
features, labels, group = ACSEmployment.df_to_numpy(acs_data)
feature_names = ACSEmployment.features
data = pd.DataFrame(features, columns = feature_names)
data.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0  26.0  21.0  5.0  17.0  2.0  0.0  5.0  1.0  4.0  1.0       2.0   2.0   2.0
# 1  21.0  20.0  5.0  17.0  2.0  0.0  1.0  3.0  4.0  1.0       1.0   2.0   2.0
# 2  18.0  16.0  5.0  17.0  2.0  0.0  2.0  3.0  4.0  1.0       1.0   2.0   2.0
# 3  85.0  16.0  2.0  16.0  1.0  0.0  1.0  1.0  4.0  4.0       1.0   1.0   2.0
# 4  19.0  19.0  5.0  17.0  2.0  0.0  1.0  1.0  4.0  2.0       1.0   2.0   2.0
#
#    DREM  SEX  RAC1P
# 0   2.0  2.0    1.0
# 1   2.0  1.0    1.0
# 2   2.0  2.0    8.0
# 3   1.0  2.0    1.0
# 4   2.0  2.0    1.0

# %%
#@markdown Drop rows with missing values
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196967 entries, 0 to 196966
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   AGEP      196967 non-null  float64
#  1   SCHL      196967 non-null  float64
#  2   MAR       196967 non-null  float64
#  3   RELP      196967 non-null  float64
#  4   DIS       196967 non-null  float64
#  5   ESP       196967 non-null  float64
#  6   CIT       196967 non-null  float64
#  7   MIG       196967 non-null  float64
#  8   MIL       196967 non-null  float64
#  9   ANC       196967 non-null  float64
#  10  NATIVITY  196967 non-null  float64
#  11  DEAR      196967 non-null  float64
#  12  DEYE      196967 non-null  float64
#  13  DREM      196967 non-null  float64
#  14  SEX       196967 non-null  float64
#  15  RAC1P     196967 non-null  float64
# dtypes: float64(16)
# memory usage: 24.0 MB

# %%
#@markdown We aggregate race to four groups and make text labels for race and sex.

# Meaning of the aggregated race categories
race_agg_names = {1: 'White',
                  2: 'Black',
                  3: 'Asian',
                  4: 'Other'}

# Meaning of the sex categories
sex_names = {1: 'Male',
             2: 'Female'}

# Aggregating race, mapping from the FolkTables' definition of RAC1P to our
# definition in race_agg_names
RAC1P_mapper = {1:1,
                2:2,
                3:4,
                4:4,
                5:4,
                6:3,
                7:4,
                8:4,
                9:4}

data['RACE_AGG'] = data['RAC1P'].map(RAC1P_mapper)
data['race_name'] = data['RACE_AGG'].map(race_agg_names)
data['sex_name'] = data['SEX'].map(sex_names)

data.drop(columns=['RAC1P'], inplace=True)

data.head()
# Out:
#    AGEP  SCHL  MAR  RELP  DIS  ESP  CIT  MIG  MIL  ANC  NATIVITY  DEAR  DEYE  \
# 0  26.0  21.0  5.0  17.0  2.0  0.0  5.0  1.0  4.0  1.0       2.0   2.0   2.0
# 1  21.0  20.0  5.0  17.0  2.0  0.0  1.0  3.0  4.0  1.0       1.0   2.0   2.0
# 2  18.0  16.0  5.0  17.0  2.0  0.0  2.0  3.0  4.0  1.0       1.0   2.0   2.0
# 3  85.0  16.0  2.0  16.0  1.0  0.0  1.0  1.0  4.0  4.0       1.0   1.0   2.0
# 4  19.0  19.0  5.0  17.0  2.0  0.0  1.0  1.0  4.0  2.0       1.0   2.0   2.0
#
#    DREM  SEX  RACE_AGG race_name sex_name
# 0   2.0  2.0         1     White   Female
# 1   2.0  1.0         1     White     Male
# 2   2.0  2.0         4     Other   Female
# 3   1.0  2.0         1     White   Female
# 4   2.0  2.0         1     White   Female

# %%
#@markdown Change data types of categorical features
numerical_cols = ['AGEP']
categorical_cols = ['SCHL','MAR','RELP','DIS','ESP','CIT','MIG','MIL','ANC','NATIVITY','DEAR','DEYE','DREM','SEX','RACE_AGG']

for col in categorical_cols:
  data[col] = data[col].astype('int')
  data[col] = data[col].astype('str')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196967 entries, 0 to 196966
# Data columns (total 18 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   AGEP       196967 non-null  float64
#  1   SCHL       196967 non-null  object
#  2   MAR        196967 non-null  object
#  3   RELP       196967 non-null  object
#  4   DIS        196967 non-null  object
#  5   ESP        196967 non-null  object
#  6   CIT        196967 non-null  object
#  7   MIG        196967 non-null  object
#  8   MIL        196967 non-null  object
#  9   ANC        196967 non-null  object
#  10  NATIVITY   196967 non-null  object
#  11  DEAR       196967 non-null  object
#  12  DEYE       196967 non-null  object
#  13  DREM       196967 non-null  object
#  14  SEX        196967 non-null  object
#  15  RACE_AGG   196967 non-null  object
#  16  race_name  196967 non-null  object
#  17  sex_name   196967 non-null  object
# dtypes: float64(1), object(17)
# memory usage: 27.0+ MB

# %%
#@markdown Standardize numerical features
scaler = StandardScaler()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])
data.head()
# Out:
#        AGEP SCHL MAR RELP DIS ESP CIT MIG MIL ANC NATIVITY DEAR DEYE DREM SEX  \
# 0 -0.672132   21   5   17   2   0   5   1   4   1        2    2    2    2   2
# 1 -0.884412   20   5   17   2   0   1   3   4   1        1    2    2    2   1
# 2 -1.011780   16   5   17   2   0   2   3   4   1        1    2    2    2   2
# 3  1.832769   16   2   16   1   0   1   1   4   4        1    1    2    1   2
# 4 -0.969324   19   5   17   2   0   1   1   4   2        1    2    2    2   2
#
#   RACE_AGG race_name sex_name
# 0        1     White   Female
# 1        1     White     Male
# 2        4     Other   Female
# 3        1     White   Female
# 4        1     White   Female

# %%
#@markdown One-hot encode categorical features

# Columns that are categorical and that the blind logistic regression algorithm
# is be allowed to predict with should be one hot encoded
one_hot_encode_cols = ['SCHL','MAR','RELP','DIS','ESP','CIT','MIG','MIL','ANC','NATIVITY','DEAR','DEYE','DREM']

data = pd.get_dummies(data, columns=one_hot_encode_cols)

data.head()
# Out:
#        AGEP SEX RACE_AGG race_name sex_name  SCHL_0  SCHL_1  SCHL_10  SCHL_11  \
# 0 -0.672132   2        1     White   Female   False   False    False    False
# 1 -0.884412   1        1     White     Male   False   False    False    False
# 2 -1.011780   2        4     Other   Female   False   False    False    False
# 3  1.832769   2        1     White   Female   False   False    False    False
# 4 -0.969324   2        1     White   Female   False   False    False    False
#
#    SCHL_12  ...  ANC_4  NATIVITY_1  NATIVITY_2  DEAR_1  DEAR_2  DEYE_1  \
# 0    False  ...  False       False        True   False    True   False
# 1    False  ...  False        True       False   False    True   False
# 2    False  ...  False        True       False   False    True   False
# 3    False  ...   True        True       False    True   False   False
# 4    False  ...  False        True       False   False    True   False
#
#    DEYE_2  DREM_0  DREM_1  DREM_2
# 0    True   False   False    True
# 1    True   False   False    True
# 2    True   False   False    True
# 3    True   False    True   False
# 4    True   False   False    True
#
# [5 rows x 91 columns]

# %% [markdown]
# #**TODO 1**: Write code to create a new column in `data` called `race_sex_name` which concatenates the `race_name` and `sex_name` columns with an underscore, so it has entries like `Black_Female` or `Other_Male`.

# %%
#@title
## TODO: WRITE CODE HERE
data['race_sex_name'] = data['race_name'] + '_' + data['sex_name']
data.head()
# Out:
#        AGEP SEX RACE_AGG race_name sex_name  SCHL_0  SCHL_1  SCHL_10  SCHL_11  \
# 0 -0.672132   2        1     White   Female   False   False    False    False
# 1 -0.884412   1        1     White     Male   False   False    False    False
# 2 -1.011780   2        4     Other   Female   False   False    False    False
# 3  1.832769   2        1     White   Female   False   False    False    False
# 4 -0.969324   2        1     White   Female   False   False    False    False
#
#    SCHL_12  ...  NATIVITY_1  NATIVITY_2  DEAR_1  DEAR_2  DEYE_1  DEYE_2  \
# 0    False  ...       False        True   False    True   False    True
# 1    False  ...        True       False   False    True   False    True
# 2    False  ...        True       False   False    True   False    True
# 3    False  ...        True       False    True   False   False    True
# 4    False  ...        True       False   False    True   False    True
#
#    DREM_0  DREM_1  DREM_2  race_sex_name
# 0   False   False    True   White_Female
# 1   False   False    True     White_Male
# 2   False   False    True   Other_Female
# 3   False    True   False   White_Female
# 4   False   False    True   White_Female
#
# [5 rows x 92 columns]

# %%
#@title
#note: here we are setting a value for the random_state (seed) parameter so that the results of this lab will remain consistent
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=4)

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (157573, 92)
# y_train shape: (157573,)
# X_test shape: (39394, 92)
# y_test shape: (39394,)

# %% [markdown]
# ## Train Logistic Regression
#
# We start again by training a straightforward Logistic Regression model on the data. We make the model blind to sex and race, but that's the only mitigation we are using.
#
# **Note:** If you have not finished TODO 1, then remove `race_sex_name` from `drop_cols`.

# %%
#@markdown Implement logistic regression

# Remove sex and race
drop_cols = ['SEX', 'RACE_AGG', 'sex_name', 'race_name', 'race_sex_name']
X_train_blind = X_train.drop(columns=drop_cols)
X_test_blind = X_test.drop(columns=drop_cols)

clf = LogisticRegression()
clf.fit(X_train_blind, y_train)
clf_accuracy = clf.score(X_test_blind, y_test)

clear_output()

print(f'Logistic Regression test accuracy: {clf_accuracy:.4f}')
# Out:
# Logistic Regression test accuracy: 0.7972

# %% [markdown]
# #2. Using Aequitas
#
# ## Preparing for Aequitas
#
# Aequitas is picky about the names of columns given to it. We have to provide the following columns:
# 1. `score` is the prediction made by our model
# 1. `label_value` is the ground-truth label
# 1. The only other columns we will keep will be our sensitive attribute labels
#
# **Note:** Keep in mind, a label of 1 means Employed and 0 means Unemployed

# %%
#@title
# Compute test predictions
y_pred = clf.predict(X_test_blind)

# Build the of information to pass to Aequitas
pred_data = X_test.filter(items=["race_name","sex_name","race_sex_name"])
pred_data['score'] = y_pred
pred_data['label_value'] = y_test

# Score and label_value are boolean by default, and we need them to be int
pred_data['score'] = pred_data['score'].astype('int')
pred_data['label_value'] = pred_data['label_value'].astype('int')
pred_data = pred_data.rename(columns={'race_name': 'race', 'sex_name': 'sex', 'race_sex_name': 'race_sex'})
# print(df.shape)
pred_data.head()
# Out:
#          race     sex      race_sex  score  label_value
# 81991   Other    Male    Other_Male      0            0
# 152046  White  Female  White_Female      0            0
# 15416   Black    Male    Black_Male      1            1
# 100832  White    Male    White_Male      0            1
# 162810  White    Male    White_Male      0            0

# %% [markdown]
# ## Getting started
#
# Much of the content of this tutorial is based off the Aequitas tutorial found at https://dssg.github.io/aequitas/examples/compas_demo.html.

# %%
#@markdown Set the color palette; very optional
aq_palette = sns.diverging_palette(225, 35, n=2)

# %% [markdown]
# Broken down by race and sex, we first look at how often, people are employed

# %%
#@title
label_by_race = sns.countplot(x="race", hue="label_value", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Employment by Race");

# %%
#@title
label_by_sex = sns.countplot(x="sex", hue="label_value", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Employment by Sex");

# %% [markdown]
# We start by plotting the predicted labels across race and sex. These already will show us where our models adds some bias.

# %%
#@markdown Inspect outcome by race

score_race = sns.countplot(x="race", hue="score", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Employment by Race");

# %%
#@title
score_sex = sns.countplot(x="sex", hue="score", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Employment by Sex");

# %% [markdown]
# #**TODO 2**: Interpret these plots. By race, which population are majority unemployed, but when predicted as majority employed? For sex, notice both men and women flip from majority unemployed to majority employed. What does this imply about our classifier across the board?

# %% [markdown]
# **Answer**:
# By race, it looks like both white and asian people are predicted as majority employed but are actually majority unemployed. Men and women are also like this when we lokk at it by sex. Both men and women are predicted as majority employed but are actually majority unemployed. This implies that our classifier is wrong. A lot of the predicted results are wrong.

# %% [markdown]
# #**TODO 3:** Write some code to compare actual and predicted employment rates by all intersections of race and sex.

# %%
#@title
# WRITE YOUR CODE HERE FOR ACTUAL EMPLOYMENT
# consider using plt.xticks(rotation = 25) to make the x-axis lables more legible
label_by_race_sex = sns.countplot(x='race_sex', hue='label_value', data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Employment by Race and Sex")
plt.xticks(rotation = 25);

# %%
#@title
# WRITE YOUR CODE HERE FOR PREDICTED EMPLOYMENT
score_race_sex = sns.countplot(x='race_sex', hue='score', data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Employment by Race and Sex")
plt.xticks(rotation = 25);

# %% [markdown]
# #**TODO 4:** Note that most white people are unemployed and most men are unemployed, but most white men are employed. How is this possible?

# %% [markdown]
# **Answer**:
#
# I think there are two potential reasons that cause this. First, there are more women than men among the most white people that are unemployed. In other words, white women takes up a larger proportion of the unemployed white people than white men. That's why most white men are employed while most white people aren't. Second, there are more black people than white people among the most men that are unemployed. In other words, black men takes up a larger proportion of the unemployed men then white men. That's why most white men are employed while most men aren't.

# %% [markdown]
# ## Using Aequitas
#
# Practitioners need a way to decide if these patterns reflect bias or not. The fact that there are many ways to detect bias makes this harder. To help with this, Aequitas provides a tool that reports a lot metrics all at once.

# %%
#@title
g = Group()
xtab, _ = g.get_crosstabs(pred_data)

# %%
#@markdown Get a sense of the predicted positives/negatives and confusion matrix
absolute_metrics = g.list_absolute_metrics(xtab)
xtab[[col for col in xtab.columns if col not in absolute_metrics]]
# Out:
#     model_id score_threshold      k attribute_name attribute_value     pp  \
# 0          0      binary 0/1  20417           race           Asian   2070
# 1          0      binary 0/1  20417           race           Black   2326
# 2          0      binary 0/1  20417           race           Other   1645
# 3          0      binary 0/1  20417           race           White  14376
# 4          0      binary 0/1  20417            sex          Female  10486
# 5          0      binary 0/1  20417            sex            Male   9931
# 6          0      binary 0/1  20417       race_sex    Asian_Female   1069
# 7          0      binary 0/1  20417       race_sex      Asian_Male   1001
# 8          0      binary 0/1  20417       race_sex    Black_Female   1271
# 9          0      binary 0/1  20417       race_sex      Black_Male   1055
# 10         0      binary 0/1  20417       race_sex    Other_Female    879
# 11         0      binary 0/1  20417       race_sex      Other_Male    766
# 12         0      binary 0/1  20417       race_sex    White_Female   7267
# 13         0      binary 0/1  20417       race_sex      White_Male   7109
#
#        pn    fp    fn     tn     tp  group_label_pos  group_label_neg  \
# 0    1347   581   205   1142   1489             1694             1723
# 1    2615   647   384   2231   1679             2063             2878
# 2    1806   464   231   1575   1181             1412             2039
# 3   13209  3413  2065  11144  10963            13028            14557
# 4    9703  3011  1406   8297   7475             8881            11308
# 5    9274  2094  1479   7795   7837             9316             9889
# 6     698   376   108    590    693              801              966
# 7     649   205    97    552    796              893              757
# 8    1334   362   208   1126    909             1117             1488
# 9    1281   285   176   1105    770              946             1390
# 10    898   278   116    782    601              717             1060
# 11    908   186   115    793    580              695              979
# 12   6773  1995   974   5799   5272             6246             7794
# 13   6436  1418  1091   5345   5691             6782             6763
#
#     group_size  total_entities
# 0         3417           39394
# 1         4941           39394
# 2         3451           39394
# 3        27585           39394
# 4        20189           39394
# 5        19205           39394
# 6         1767           39394
# 7         1650           39394
# 8         2605           39394
# 9         2336           39394
# 10        1777           39394
# 11        1674           39394
# 12       14040           39394
# 13       13545           39394

# %% [markdown]
# Aequitas uses some names and acronyms unlike what we have used in class:
# - `precision` is PPV
# - `ppr` $ = \frac{\text{PP}_G}{P}$ where $P$ is the total number of people predicted positive across all groups, and $\text{PP}_G$ is the number of people in group $G$ predicted positive.
# - `pprev` is the Selection Rate
# - `prev` is the Prevalence

# %%
#@markdown View calculated "absolute metrics" (like false positive rates) for each group
xtab[['attribute_name', 'attribute_value'] + absolute_metrics].round(2)
# Out:
#    attribute_name attribute_value  accuracy   tpr   tnr   for   fdr   fpr  \
# 0            race           Asian      0.77  0.88  0.66  0.15  0.28  0.34
# 1            race           Black      0.79  0.81  0.78  0.15  0.28  0.22
# 2            race           Other      0.80  0.84  0.77  0.13  0.28  0.23
# 3            race           White      0.80  0.84  0.77  0.16  0.24  0.23
# 4             sex          Female      0.78  0.84  0.73  0.14  0.29  0.27
# 5             sex            Male      0.81  0.84  0.79  0.16  0.21  0.21
# 6        race_sex    Asian_Female      0.73  0.87  0.61  0.15  0.35  0.39
# 7        race_sex      Asian_Male      0.82  0.89  0.73  0.15  0.20  0.27
# 8        race_sex    Black_Female      0.78  0.81  0.76  0.16  0.28  0.24
# 9        race_sex      Black_Male      0.80  0.81  0.79  0.14  0.27  0.21
# 10       race_sex    Other_Female      0.78  0.84  0.74  0.13  0.32  0.26
# 11       race_sex      Other_Male      0.82  0.83  0.81  0.13  0.24  0.19
# 12       race_sex    White_Female      0.79  0.84  0.74  0.14  0.27  0.26
# 13       race_sex      White_Male      0.81  0.84  0.79  0.17  0.20  0.21
#
#      fnr   npv  precision   ppr  pprev  prev
# 0   0.12  0.85       0.72  0.10   0.61  0.50
# 1   0.19  0.85       0.72  0.11   0.47  0.42
# 2   0.16  0.87       0.72  0.08   0.48  0.41
# 3   0.16  0.84       0.76  0.70   0.52  0.47
# 4   0.16  0.86       0.71  0.51   0.52  0.44
# 5   0.16  0.84       0.79  0.49   0.52  0.49
# 6   0.13  0.85       0.65  0.05   0.60  0.45
# 7   0.11  0.85       0.80  0.05   0.61  0.54
# 8   0.19  0.84       0.72  0.06   0.49  0.43
# 9   0.19  0.86       0.73  0.05   0.45  0.40
# 10  0.16  0.87       0.68  0.04   0.49  0.40
# 11  0.17  0.87       0.76  0.04   0.46  0.42
# 12  0.16  0.86       0.73  0.36   0.52  0.44
# 13  0.16  0.83       0.80  0.35   0.52  0.50

# %% [markdown]
# ## How do we understand biases in our model?
#
# One of the major contributions of the Aequitas toolkit and enviornment is the `Fairness Tree`.
#
# While a lot of bias metrics and fairness definitions have been proposed, there is no consensus on which definitions and metrics should be used in practice to evaluate and audit these systems. To help with this, the authors of Aequitas also created a guide for understanding when and what metrics might apply in a given situation, called the `Fairness Tree`. It can be found here: http://www.datasciencepublicpolicy.org/our-work/tools-guides/aequitas/

# %% [markdown]
# Consider the following scenario:
#
# Suppose a certain country in Europe is building a model to predict the risk that a criminal is going to recidivate, similiar to the prediction made by the COMPAS model discussed in class.  However, in contrast to COMPAS, the goal is not to use these scores to determine whether or not an individual is allowed to be free; instead, almost all individuals with a high risk score will be admitted into a special program that has three components:  (1) the individuals recieve one-on-one counseling, (2) the individuals will recieve a monthly stipend, and (3) the individuals are set up with housing.  The program is a benefit to the individuals and is aimed at reducing recividism.
#
# Think about the confusion matrix for the model.  How would you define the positive and negative class?
#
# Suppose the country is trying to decide on the proper fairness metric to use for their machine learning model, and cares about the protected attribute race.  In terms of representation, they would either accept a model that has equal nominal representation of different races, or equal proportional representation in the special program.  They are also concerned about errors made by the model, and want to make sure that predictive equity among groups is acheieved for people with need.
#
# Review the Aequitas guidelines for fairness metrics, and think about them in the context of this problem:  http://www.datasciencepublicpolicy.org/projects/aequitas/.
#
#
# **Question:** Which of the following is NOT a good choice for a fairness metric for the model?
#
# > a) False Negative Rate Parity \
# > b) Equal Selection Parity \
# > c) Demographic Parity \
# > d) False Positive Rate Parity
#
# d) False Positive Rate Parity

# %% [markdown]
# #**TODO 5:** Justify your answer to the question above. Suppose the country wants to ensure that whether or not someone fails to get helped does not depend on their race. Which specific metric should they use then?

# %% [markdown]
# **Answer:**
#
#
# False Positive Rate Parity is not a good choice for a fairness metric for this model because False Negative Rate Parity, Equal Selection Parity, and Demographic Parity are more commonly used to assess and mitigate biases in machine learning models, particularly in scenarios where fairness across different demographic groups is important.
#
# In this case, they should use Demographic Parity to ensure that whether or not someone fails to get helped does not depend on their race. Demographic Parity requires that the proportion of positive outcomes remains equal across different demographic groups, regardless of their race. This means that the outcome should be distributed fairly among all racial groups, without any bias favoring or disadvantaging a particular group based on their race.

# %% [markdown]
# ## What is the scenario of our data?

# %% [markdown]
# In order to understand what metric (or metrics) we care about for the Folktables employment prediction, we need to know the full context of use, which isn't available. We will have to make one up:
# - Suppose the IRS is deciding who to audit. The training data for this tool was authentic random census data, but the test data entirely describes people who listed themselves as unemployed on their tax forms. People predicted to be employed are more likely to get audited.
#
# Ideally, these audits should be distributed evenly across groups and not target one race in particular. These audits can be thought of as a *punitive* intervention, because they may result in penalties, fines, or even jail time.
#
# We could argue in favor of several different fairness metrics that are appropiate for this case: *Demographic Parity*, *False Discovery Rate Parity*, and *False Positive Rate Parity*. In this lab, we will use consider the last one (*FPR Parity*).

# %%
#@markdown Write down the confusion matrix data again

xtab[['attribute_name', 'attribute_value'] + absolute_metrics].round(2)
# Out:
#    attribute_name attribute_value  accuracy   tpr   tnr   for   fdr   fpr  \
# 0            race           Asian      0.77  0.88  0.66  0.15  0.28  0.34
# 1            race           Black      0.79  0.81  0.78  0.15  0.28  0.22
# 2            race           Other      0.80  0.84  0.77  0.13  0.28  0.23
# 3            race           White      0.80  0.84  0.77  0.16  0.24  0.23
# 4             sex          Female      0.78  0.84  0.73  0.14  0.29  0.27
# 5             sex            Male      0.81  0.84  0.79  0.16  0.21  0.21
# 6        race_sex    Asian_Female      0.73  0.87  0.61  0.15  0.35  0.39
# 7        race_sex      Asian_Male      0.82  0.89  0.73  0.15  0.20  0.27
# 8        race_sex    Black_Female      0.78  0.81  0.76  0.16  0.28  0.24
# 9        race_sex      Black_Male      0.80  0.81  0.79  0.14  0.27  0.21
# 10       race_sex    Other_Female      0.78  0.84  0.74  0.13  0.32  0.26
# 11       race_sex      Other_Male      0.82  0.83  0.81  0.13  0.24  0.19
# 12       race_sex    White_Female      0.79  0.84  0.74  0.14  0.27  0.26
# 13       race_sex      White_Male      0.81  0.84  0.79  0.17  0.20  0.21
#
#      fnr   npv  precision   ppr  pprev  prev
# 0   0.12  0.85       0.72  0.10   0.61  0.50
# 1   0.19  0.85       0.72  0.11   0.47  0.42
# 2   0.16  0.87       0.72  0.08   0.48  0.41
# 3   0.16  0.84       0.76  0.70   0.52  0.47
# 4   0.16  0.86       0.71  0.51   0.52  0.44
# 5   0.16  0.84       0.79  0.49   0.52  0.49
# 6   0.13  0.85       0.65  0.05   0.60  0.45
# 7   0.11  0.85       0.80  0.05   0.61  0.54
# 8   0.19  0.84       0.72  0.06   0.49  0.43
# 9   0.19  0.86       0.73  0.05   0.45  0.40
# 10  0.16  0.87       0.68  0.04   0.49  0.40
# 11  0.17  0.87       0.76  0.04   0.46  0.42
# 12  0.16  0.86       0.73  0.36   0.52  0.44
# 13  0.16  0.83       0.80  0.35   0.52  0.50

# %%
#@markdown Plot the FPR within each group. The darker a bar is, the more people belong to that group.

aqp = Plot()
fnr = aqp.plot_group_metric(xtab, 'fpr')

# Note: if you have small group sizes, you can use the 'min_group_size' parameter:
# fnr = aqp.plot_group_metric(xtab, 'fnr', min_group_size=0.05)

# %%
#@markdown We can look at all three metrics we discussed: Demographic Parity (pprev/selection rate), FDR, and FPR
p = aqp.plot_group_metric_all(xtab, metrics=['pprev','fpr','fdr'], ncols=3)

# %% [markdown]
# #**TODO 6:** Looking at the plot FPR here, we see that Asian women are the most discriminated against group by this model. Now look back at the bar plots between TODO 3 and TODO 4. Based on those bar plots, would you describe this bias against women as _Pre-Existing_ or _Technical_?

# %% [markdown]
# **Answer:**
#
# Comparing to the bar plots in TODO 3 and TODO 4, I would describe this bias as both pre-existing and technical. I think the bias is pre-existing because the previous bar plots also show that Asian women are discriminated. The plots show a difference between the actual and predicted employment of Asian women: most are unemployed in reality while most are employed in prediction. This shows that the FPR for Asian women is high and agrees with this plot above. Therefore, this bias is pre-existing. However, I argue it is also technical because the previous bar plots don't show that Asian women are the most discriminated. We can only conclude that Asian women are discriminated but not the most. The previous bar plots show that White women possess the greatest difference between the actual and predicted outcomes. In other words, the previous bar plots show that White women are the most discriminated against group by this model, which does not accord with the FPR plot above. Therefore, this bias is also technical as such difference is generating from our analysis.

# %% [markdown]
# #**TODO 7:**
# What do we learn about the FPR on Asian men and Asian women that we cannot figure out by just looking at the FPR across race and gender individually?

# %% [markdown]
# **Answer:**
#
# Just like my argument from last question, we wouldn't know that Asian men and Asian women have such a high FPR if we are only looking at FPR across race or gender. Furthermore, the difference between Asian men and Asian women is greater than male and female. So there are a lot more insights that we can gain by looking at the FPR across race and gender, both themselves and when comparing to other groups.

# %% [markdown]
# ## Measuring bias with disparity
#
# Typically, error-based metrics judge the fairness of a predictor by considering the *imbalance* between group-specific metrics. We can calculate imbalance as a difference --- mean, squared, absolute, etc. --- or as a **disparity** --- the ratio of a metric of one group, $g_j$, to that of a *reference group*, $g_{ref}$, usually chosen as the majority group:
#
# $disparity_{g_j} = \frac{metric_{g_j}}{metric_{g_{ref}}}$
#
# Generally, we require as a rule-of-thumb that $ 0.8 \leq disparity \leq 1.2$ (i.e. the metrics are within approx. 20% of each other).
#
# Disparity ratios have been nice properties. For example, they are robust to small real values. Consider a model that has $fpr_1 = 0.002$ for one group and $fpr_2 = 0.04$ for the other. These values would satisfy a seemingly strict fairness constraint where $|fpr_1 - fpr_2| <= 0.05$, but this is likely not desirable to practitioners. Instead, using disparity ratios, this scenario would be considered unfair since $0.8 \nleq \frac{fpr_1}{fpr_2} \leq 1.2$.

# %%
#@title
b = Bias()
bdf = b.get_disparity_predefined_groups(xtab, original_df=pred_data, ref_groups_dict={'race':'White', 'sex':'Male', 'race_sex': 'White_Male'}, alpha=0.05, mask_significance=True)

# %%
#@title
calculated_disparities = b.list_disparities(bdf)
bdf[['attribute_name', 'attribute_value'] +  ['fpr_disparity', 'pprev_disparity', 'fdr_disparity']]

# Look for disparity values outside of the bounds 0.8 <= disparity <= 1.2
# Out:
#    attribute_name attribute_value  fpr_disparity  pprev_disparity  \
# 0            race           Asian       1.438224         1.162413
# 1            race           Black       0.958846         0.903295
# 2            race           Other       0.970591         0.914652
# 3            race           White       1.000000         1.000000
# 4             sex          Female       1.257479         1.004422
# 5             sex            Male       1.000000         1.000000
# 6        race_sex    Asian_Female       1.856410         1.152688
# 7        race_sex      Asian_Male       1.291579         1.155901
# 8        race_sex    Black_Female       1.160296         0.929626
# 9        race_sex      Black_Male       0.977897         0.860498
# 10       race_sex    Other_Female       1.250841         0.942480
# 11       race_sex      Other_Male       0.906136         0.871854
# 12       race_sex    White_Female       1.220803         0.986185
# 13       race_sex      White_Male       1.000000         1.000000
#
#     fdr_disparity
# 0        1.182245
# 1        1.171646
# 2        1.188102
# 3        1.000000
# 4        1.361812
# 5        1.000000
# 6        1.763366
# 7        1.026720
# 8        1.427892
# 9        1.354331
# 10       1.585580
# 11       1.217353
# 12       1.376322
# 13       1.000000

# %% [markdown]
# Notice The FPR disparity for race="Asian" is 1.44. That means that Asian folks in the dataset have an FPR 1.44x that of White folks.
#
# We can also look at mosaic plots of the disparity. In these plots, the size of each block corresponds to the relative size of the population.

# %%
#@title
aqp.plot_disparity(bdf, group_metric='fpr_disparity', attribute_name='race')

# %%
#@title
majority_bdf = b.get_disparity_major_group(xtab, original_df=pred_data, mask_significance=True)
j = aqp.plot_disparity_all(majority_bdf, metrics=['pprev_disparity','fdr_disparity','fpr_disparity'], significance_alpha=0.05)

# %% [markdown]
# We can also apply statistical testing to see if disparities are significantly different from each other.
#
# Those mosaics colored in green are those that have *Parity* between metrics at an $\alpha = 0.05$ significance level, and red indicates they have *disparity*.

# %%
#@title
f = Fairness()
fdf = f.get_group_value_fairness(bdf)
parity_detrminations = f.list_parities(fdf)
fdf[['attribute_name', 'attribute_value'] + absolute_metrics + calculated_disparities + parity_detrminations].style
m = aqp.plot_fairness_disparity(fdf, group_metric='fpr', attribute_name='race')

# %%
#@title
m = aqp.plot_fairness_disparity(fdf, group_metric='pprev', attribute_name='race')

# %%
#@title
m = aqp.plot_fairness_disparity(fdf, group_metric='fdr', attribute_name='race')

# %% [markdown]
# For this model, it seems like our biggest issue is a FPR disparity for Asain folks as compared to White folks.
#
# If we took this tutorial one step further an applied bias mitigation, this would be an appropiate target.

# %% [markdown]
# #**TODO 8:** Write some code to test for statistical disparity across race and sex intersectionally.

# %%
#@title
## YOUR CODE HERE
m = aqp.plot_fairness_disparity(fdf, group_metric='fpr', attribute_name='race_sex')

# %%
m = aqp.plot_fairness_disparity(fdf, group_metric='pprev', attribute_name='race_sex')

# %%
m = aqp.plot_fairness_disparity(fdf, group_metric='fdr', attribute_name='race_sex')
